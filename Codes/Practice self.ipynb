# %%
import pandas as pd
from matplotlib import pyplot as plt
filepath = "C:/Users/DELL/OneDrive/Desktop/IIT DHANBAD SAMRAT/7. Multivariate Lab/Lab 12th Oct/Reg6.xlsx"
df = pd.read_excel(filepath)
df
# Out:
#     Observation  Age  Severity  Surg - Med  Anxiety  Satisfaction  Unnamed: 6  \
# 0             1   55        50           0      2.1            68         NaN
# 1             2   46        24           1      2.8            77         NaN
# 2             3   30        46           1      3.3            96         NaN
# 3             4   35        48           1      4.5            80         NaN
# 4             5   59        58           0      2.0            43         NaN
# 5             6   61        60           0      5.1            44         NaN
# 6             7   74        65           1      5.5            26         NaN
# 7             8   38        42           1      3.2            88         NaN
# 8             9   27        42           0      3.1            75         NaN
# 9            10   51        50           1      2.4            57         NaN
# 10           11   53        38           1      2.2            56         NaN
# ...

# %%
df.columns
# Out:
# Index(['Observation', 'Age', 'Severity', 'Surg - Med', 'Anxiety',
#        'Satisfaction', 'Unnamed: 6', 'Unnamed: 7'],
#       dtype='object')

# %%
fh = df.loc[:, ['Satisfaction', 'Anxiety']].copy()
fh
# Out:
#     Satisfaction  Anxiety
# 0             68      2.1
# 1             77      2.8
# 2             96      3.3
# 3             80      4.5
# 4             43      2.0
# 5             44      5.1
# 6             26      5.5
# 7             88      3.2
# 8             75      3.1
# 9             57      2.4
# 10            56      2.2
# 11            88      2.1
# 12            88      1.9
# 13           102      3.1
# 14            88      3.0
# 15            70      4.2
# 16            52      4.6
# 17            43      5.3
# 18            46      7.2
# 19            56      7.8
# 20            59      7.0
# 21            26      6.2
# 22            52      4.1
# 23            83      3.5
# 24            75      2.1

# %%
dfclean = df.loc[:, ['Unnamed: 6', 'Unnamed: 7']].copy()
dfclean
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dfclean = df.loc[:, ['Unnamed: 6', 'Unnamed: 7']].copy()
#       2 dfclean
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1067, in _LocationIndexer.__getitem__(self, key)
#    1065     if self._is_scalar_access(key):
#    1066         return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067     return self._getitem_tuple(key)
#    1068 else:
#    1069     # we by definition only have the 0th axis
#    1070     axis = self.axis or 0
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:1256, in _LocIndexer._getitem_tuple(self, tup)
#    1253 if self._multi_take_opportunity(tup):
#    1254     return self._multi_take(tup)
# -> 1256 return self._getitem_tuple_same_dim(tup)
#
# ...

# %%
df.drop(['gender', 'education', 'age'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['A1', 'A2', 'A3', 'A4', 'A5', 'C1', 'C2', 'C3', 'C4', 'C5', 'E1', 'E2',
#        'E3', 'E4', 'E5', 'N1', 'N2', 'N3', 'N4', 'N5', 'O1', 'O2', 'O3', 'O4',
#        'O5'],
#       dtype='object')

# %%
df.shape
# Out:
# (2800, 25)

# %%
df.dropna(inplace = True)

# %%
df.shape
# Out:
# (2436, 25)

# %%
plt.boxplot(df)
plt.title("Finding out the Outliers")
plt.xlabel("Columns")
plt.ylabel("Data")
plt.show()

# %%
upperlimit = df['C1'].mean() + 3*df['C1'].std()
lowerlimit = df['C1'].mean() - 3*df['C1'].std()
print(upperlimit,lowerlimit)
# Out:
# 8.230813919221209 0.8192681825850316

# %%
outliers=df.loc[(df['C1']>upperlimit) | (df['C1']<lowerlimit) ]
outliers
# Out:
# Empty DataFrame
# Columns: [A1, A2, A3, A4, A5, C1, C2, C3, C4, C5, E1, E2, E3, E4, E5, N1, N2, N3, N4, N5, O1, O2, O3, O4, O5]
# Index: []
#
# [0 rows x 25 columns]

# %%
maxthreshold = df['A5'].quantile(0.99)
minthreshold = df['A5'].quantile(0.01)
print(maxthreshold,minthreshold)
# Out:
# 6.0 1.0

# %%
Outliers = pd.DataFrame()
type(Outliers)
# Out:
# pandas.core.frame.DataFrame

# %%
outliers = df.loc[(df['A5']>maxthreshold) | (df['A5']<minthreshold)]
outliers
# Out:
# Empty DataFrame
# Columns: [A1, A2, A3, A4, A5, C1, C2, C3, C4, C5, E1, E2, E3, E4, E5, N1, N2, N3, N4, N5, O1, O2, O3, O4, O5]
# Index: []
#
# [0 rows x 25 columns]

# %%
len(df)

# %%
for i to df.shape

outliers = df[df['A5']>maxthreshold]

# %%
outliers
# Out:
# Empty DataFrame
# Columns: [A1, A2, A3, A4, A5, C1, C2, C3, C4, C5, E1, E2, E3, E4, E5, N1, N2, N3, N4, N5, O1, O2, O3, O4, O5]
# Index: []
#
# [0 rows x 25 columns]
